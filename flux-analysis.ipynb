# %%
import xml.etree.ElementTree as ET
import pandas as pd

# %% [markdown]
# ## Leitura dos Dados

# %%
data = []

tree = ET.parse('resultados-completos.xml')
root = tree.getroot()

# timesteps
for child in root:
	# edge
	for subchild in child:
		# lane
		for subsubchild in subchild:
			# vehicle
			for subsubsubchild in subsubchild:
				new_row = [child.attrib['time'], subchild.attrib['id'], subsubchild.attrib['id'], subsubsubchild.attrib['id'], subsubsubchild.attrib['pos'], subsubsubchild.attrib['speed']]
				data.append(new_row)

df = pd.DataFrame(data, columns=['time', 'edge', 'lane', 'vehicle', 'pos', 'speed'])

df.head(10)
# Out:
#    time       edge         lane  vehicle    pos speed
# 0  0.00  sai-morro  sai-morro_0  F1MAM.0   5.10  0.00
# 1  0.00     sai-sp     sai-sp_0  F1SMM.0   2.30  0.00
# 2  0.00     sai-sp     sai-sp_1  F1SAM.0   5.10  0.00
# 3  0.00     sai-uf     sai-uf_1  F1UAM.0   5.10  0.00
# 4  1.00  sai-morro  sai-morro_0  F1MAM.0   7.22  2.12
# 5  1.00     sai-sp     sai-sp_0  F1SMM.0   6.89  4.59
# 6  1.00     sai-sp     sai-sp_1  F1SAM.0   6.50  1.40
# 7  1.00     sai-uf     sai-uf_0  F1UAS.0   5.10  0.00
# 8  1.00     sai-uf     sai-uf_1  F1UAM.0   7.06  1.96
# 9  2.00  sai-morro  sai-morro_0  F1MAM.0  11.77  4.55

# %% [markdown]
# ## Fazendo o tracking de um carro

# %% [markdown]
# É possível ver que começa nas edges de "sai-xxxxxx", por exemplo e termina em "ent-xxxxxx"

# %%
# track a vehicle
df[df['vehicle'] == 'F1MAM.0']
# Out:
#        time           edge             lane  vehicle     pos  speed
# 0      0.00      sai-morro      sai-morro_0  F1MAM.0    5.10   0.00
# 4      1.00      sai-morro      sai-morro_0  F1MAM.0    7.22   2.12
# 9      2.00      sai-morro      sai-morro_0  F1MAM.0   11.77   4.55
# 17     3.00      sai-morro      sai-morro_0  F1MAM.0   18.15   6.38
# 27     4.00      sai-morro      sai-morro_0  F1MAM.0   26.64   8.49
# 37     5.00      sai-morro      sai-morro_0  F1MAM.0   37.63  11.00
# 50     6.00      sai-morro      sai-morro_0  F1MAM.0   51.10  13.47
# 65     7.00      sai-morro      sai-morro_0  F1MAM.0   65.66  14.56
# 79     8.00      sai-morro      sai-morro_0  F1MAM.0   79.55  13.89
# 99     9.00      sai-morro      sai-morro_0  F1MAM.0   92.98  13.42
# 119   10.00      sai-morro      sai-morro_0  F1MAM.0  106.57  13.60
# 140   11.00      sai-morro      sai-morro_0  F1MAM.0  120.44  13.86
# 159   12.00      sai-morro      sai-morro_0  F1MAM.0  131.96  11.52
# 173   13.00   -118998146#2   -118998146#2_0  F1MAM.0    4.61   7.40
# 198   14.00   -118998146#2   -118998146#2_0  F1MAM.0   14.56   9.95
# 223   15.00   -118998146#2   -118998146#2_0  F1MAM.0   27.04  12.48
# 247   16.00   -118998146#2   -118998146#2_0  F1MAM.0   41.51  14.47
# 274   17.00   -118998146#2   -118998146#2_0  F1MAM.0   58.16  16.65
# 301   18.00   -118998146#2   -118998146#2_0  F1MAM.0   77.21  19.06
# 329   19.00   -118998146#2   -118998146#2_0  F1MAM.0   98.63  21.41
# 356   20.00   -118998146#2   -118998146#2_0  F1MAM.0  122.25  23.63
# 383   21.00   -118998146#2   -118998146#2_0  F1MAM.0  148.08  25.83
# 411   22.00   -118998146#2   -118998146#2_0  F1MAM.0  176.03  27.95
# 437   23.00   -118998146#1   -118998146#1_0  F1MAM.0   19.97  28.69
# 467   24.00   -118998146#1   -118998146#1_0  F1MAM.0   48.19  28.22
# 498   25.00   -118998146#1   -118998146#1_0  F1MAM.0   76.36  28.18
# 533   26.00   -118998146#0   -118998146#0_0  F1MAM.0   19.20  28.29
# 563   27.00   -118998146#0   -118998146#0_0  F1MAM.0   48.03  28.83
# 595   28.00   -118998146#0   -118998146#0_0  F1MAM.0   76.84  28.81
# 637   29.00    964405646#0    964405646#0_0  F1MAM.0    1.99  24.31
# 671   30.00    964405646#0    964405646#0_0  F1MAM.0   22.00  20.01
# 712   31.00     sai-morro2     sai-morro2_0  F1MAM.0   10.51  15.83
# 747   32.00     sai-morro2     sai-morro2_0  F1MAM.0   21.91  11.40
# 782   33.00     sai-morro2     sai-morro2_0  F1MAM.0   28.81   6.90
# 819   34.00     sai-morro2     sai-morro2_0  F1MAM.0   31.21   2.40
# 854   35.00     sai-morro2     sai-morro2_0  F1MAM.0   31.47   0.25
# 889   36.00     sai-morro2     sai-morro2_0  F1MAM.0   31.48   0.01
# 901   37.00  :1337694471_0  :1337694471_0_0  F1MAM.0    1.70   1.81
# 935   38.00  :1337694471_0  :1337694471_0_0  F1MAM.0    5.54   3.84
# 978   39.00    118998150#1    118998150#1_0  F1MAM.0    5.08   5.79
# 1002  40.00  :2815570999_1  :2815570999_1_0  F1MAM.0    1.19   8.00
# 1034  41.00  :1337694466_2  :1337694466_2_1  F1MAM.0    0.85   7.82
# 1066  42.00  :1337694466_2  :1337694466_2_1  F1MAM.0    9.48   8.64
# 1104  43.00  :4808995242_2  :4808995242_2_0  F1MAM.0    1.42   8.02
# 1139  44.00  :4808995242_2  :4808995242_2_0  F1MAM.0    8.31   6.89
# 1182  45.00    118998150#5    118998150#5_0  F1MAM.0    6.07   7.53
# 1213  46.00      ent-morro      ent-morro_0  F1MAM.0    3.09   7.32
# 1247  47.00      ent-morro      ent-morro_0  F1MAM.0   12.31   9.22
# 1281  48.00      ent-morro      ent-morro_0  F1MAM.0   23.64  11.33

# %% [markdown]
# Todas as edges de "saída", que na verdade são de entrada.

# %%
# all edges (that begin with 'ent')
df[df['edge'].str.startswith('ent')]['edge'].unique()
# Out:
# array(['ent-morro', 'ent-uf', 'ent-sp'], dtype=object)

# %% [markdown]
# Fazer uma função que conta o fluxo (carros diferentes / tempo) em uma edge específica.

# %%
# a function that gets the flux of a given edge with a given time interval size
def calc_flux(df, edge):
	df_edge = df[df['edge'] == edge]
	df_edge['time'] = df_edge['time'].astype(float)
	df_edge['time'] = df_edge['time'] // time_interval
	df_edge['time'] = df_edge['time'] * time_interval
	df_edge = df_edge.groupby('time').count()
	df_edge = df_edge.reset_index()
	df_edge = df_edge.rename(columns={'vehicle': 'flux'})
	df_edge['flux'] = df_edge['flux'] / time_interval
	return df_edge

# %% [markdown]
# - Já possuíamos uma contagem dos carros em 5 tipos: Carro, Moto, Ônibus, Van e Caminhão
# - Para a análise aqui feita e ajuste de parâmetros futuro, vamos simplificar
# - Apenas 2 tipos:
# 	- Carro (individual: acumulará a contagem de todos os 4 exceto ônibus e moto)
# 	- Ônibus
# - Motos desconsideradas
# - Servirá também para a análise futura de "mais ônibus menos carro ajuda a não saturação do sistema?"
# - Para essa análise futura também precisamos verificar se a saturação ocorre e seu nome científico
# ![Alt text](https://lh3.googleusercontent.com/keep-bbsk/AFgXFlK9jk5UWA3f0vkiAMDtz4ugqpyjdVDAPTNMGJ7UZtNuWHMj0blhVSE_WaJIbuSZ-IWgd3xi8wQXCmRI-g94sa3NQXhSNGbeffpzq9VinEPqEo6BVg_bLw=s600 "a title")

# %%
experimental_data = [
	['morro', 0, 'carro',   2, 49, 15],
	['morro', 1, 'carro',   3, 43,  9],
	['morro', 2, 'carro',   2, 54, 16],
	['morro', 0, 'onibus',  0,  1,  1],
	['morro', 1, 'onibus',  0,  1,  0],
	['morro', 2, 'onibus',  0,  0,  0],
	['UF',    0, 'carro',  78,  0, 61],
	['UF',    1, 'carro',  82,  1, 57],
	['UF',    2, 'carro',  89,  0, 74],
	['UF',    0, 'onibus',  0,  0,  2],
	['UF',    1, 'onibus',  0,  0,  1],
	['UF',    2, 'onibus',  1,  0,  0],
	['SP',    0, 'carro',  32, 91,  2],
	['SP',    1, 'carro',  50, 76,  4],
	['SP',    2, 'carro',  41, 78,  8],
	['SP',    0, 'onibus',  3,  1,  0],
	['SP',    1, 'onibus',  1,  3,  0],
	['SP',    2, 'onibus',  4,  1,  0]
]

experimental_df = pd.DataFrame(experimental_data, columns=['entrada', 'intervalo', 'veiculo', 'saida-morro', 'saida-UF', 'saida-SP'])
experimental_df = experimental_df.melt(id_vars=['entrada', 'intervalo', 'veiculo'], value_vars=['saida-morro', 'saida-UF', 'saida-SP'], var_name='saida', value_name='contagem')
experimental_df['saida'] = experimental_df['saida'].str.replace('saida-', '')
experimental_df = experimental_df[['entrada', 'saida', 'intervalo', 'veiculo', 'contagem']]
experimental_df = experimental_df.sort_values(by=['entrada', 'saida', 'intervalo', 'veiculo'])

experimental_df
# Out:
#    entrada  saida  intervalo veiculo  contagem
# 48      SP     SP          0   carro         2
# 51      SP     SP          0  onibus         0
# 49      SP     SP          1   carro         4
# 52      SP     SP          1  onibus         0
# 50      SP     SP          2   carro         8
# 53      SP     SP          2  onibus         0
# 30      SP     UF          0   carro        91
# 33      SP     UF          0  onibus         1
# 31      SP     UF          1   carro        76
# 34      SP     UF          1  onibus         3
# 32      SP     UF          2   carro        78
# 35      SP     UF          2  onibus         1
# 12      SP  morro          0   carro        32
# 15      SP  morro          0  onibus         3
# 13      SP  morro          1   carro        50
# 16      SP  morro          1  onibus         1
# 14      SP  morro          2   carro        41
# 17      SP  morro          2  onibus         4
# 42      UF     SP          0   carro        61
# 45      UF     SP          0  onibus         2
# 43      UF     SP          1   carro        57
# 46      UF     SP          1  onibus         1
# 44      UF     SP          2   carro        74
# 47      UF     SP          2  onibus         0
# 24      UF     UF          0   carro         0
# 27      UF     UF          0  onibus         0
# 25      UF     UF          1   carro         1
# 28      UF     UF          1  onibus         0
# 26      UF     UF          2   carro         0
# 29      UF     UF          2  onibus         0
# 6       UF  morro          0   carro        78
# 9       UF  morro          0  onibus         0
# 7       UF  morro          1   carro        82
# 10      UF  morro          1  onibus         0
# 8       UF  morro          2   carro        89
# 11      UF  morro          2  onibus         1
# 36   morro     SP          0   carro        15
# 39   morro     SP          0  onibus         1
# 37   morro     SP          1   carro         9
# 40   morro     SP          1  onibus         0
# 38   morro     SP          2   carro        16
# 41   morro     SP          2  onibus         0
# 18   morro     UF          0   carro        49
# 21   morro     UF          0  onibus         1
# 19   morro     UF          1   carro        43
# 22   morro     UF          1  onibus         1
# 20   morro     UF          2   carro        54
# 23   morro     UF          2  onibus         0
# 0    morro  morro          0   carro         2
# 3    morro  morro          0  onibus         0
# 1    morro  morro          1   carro         3
# 4    morro  morro          1  onibus         0
# 2    morro  morro          2   carro         2
# 5    morro  morro          2  onibus         0
